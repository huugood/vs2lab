# %% [markdown]
# # Running server and client in separate notebooks - client part
#
# Here we start the client. The server needs to be started first. Lets go....

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

client.call() # start the call and print echo
# Out:
# 2025-10-28 19:42:16,941 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=81, family=2, type=1, proto=0, laddr=('127.0.0.1', 49328), raddr=('127.0.0.1', 50007)>
# 2025-10-28 19:42:16,942 - vs2lab.a1_layers.clientserver.Client - INFO - Msg length 8
# 2025-10-28 19:42:16,943 - vs2lab.a1_layers.clientserver.Client - INFO - Sending message: b'\x00\x00\x00\x08GET\njack'
# 2025-10-28 19:42:16,949 - vs2lab.a1_layers.clientserver.Client - INFO - Message received: 'FOUND\n4098'
# 2025-10-28 19:42:16,950 - vs2lab.a1_layers.clientserver.Client - INFO - Command: FOUND
# 2025-10-28 19:42:16,950 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# 4098
# '4098'

# %% [markdown]
# Finished.
